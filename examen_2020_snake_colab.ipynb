# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Lanceur pour l'examen 2020 - Snake
# 1) Adapte le chemin ci-dessous vers ton dossier '1ereB_info' sur le Drive, si nécessaire.

import os, sys

# Dossier racine sur le Drive partagé (1ereB_info)
BASE = "/content/drive/MyDrive/1ereB_info"

os.chdir(BASE)
print("Répertoire courant:", os.getcwd())

# 2) Importer et lancer le grader de l'examen
import importlib.util

spec = importlib.util.spec_from_file_location(
    "grader_examen_2020_snake",
    os.path.join(BASE, "grader_examen_2020_snake.py"),
)
mod = importlib.util.module_from_spec(spec)
spec.loader.exec_module(mod)

if __name__ == "__main__":
    mod.main()
