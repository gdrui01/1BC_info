# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Lanceur pour l'examen 2022 - Q1 Code de César

import os, sys, importlib.util

# Dossier racine sur le Drive partagé (1ereB_info)
BASE = "/content/drive/MyDrive/1ereB_info"

os.chdir(BASE)
print("Répertoire courant:", os.getcwd())

spec = importlib.util.spec_from_file_location(
    "grader_examen_2022_q1_cesar",
    os.path.join(BASE, "grader_examen_2022_q1_cesar.py"),
)
mod = importlib.util.module_from_spec(spec)
spec.loader.exec_module(mod)

if __name__ == "__main__":
    mod.main()
